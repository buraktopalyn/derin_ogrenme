# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import load_model, Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical, plot_model

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape, train_labels.shape
# Out:
# ((60000, 28, 28), (60000,))

# %%
test_images.shape, test_labels.shape
# Out:
# ((10000, 28, 28), (10000,))

# %%
outputs = np.unique(train_labels).shape[0]

# %%
def vis_img(data):
  plt.figure(figsize=(5, 5))
  for i in range(15):
      plt.subplot(5, 5, i + 1)
      plt.imshow(train_images[i], cmap='gray')
      plt.title(f"Label: {train_labels[i]}", fontsize=10)
      plt.axis('off')
  plt.tight_layout()

# %%
vis_img(train_images)

# %%
plt.figure(figsize=(7,7))
plt.imshow(train_images[197], cmap="gray")
plt.axis("off")
rows, cols = train_images[197].shape
for i in range(rows):
    for j in range(cols):
        if train_images[197][i, j] > 120:
            plt.text(j, i, str(train_images[197][i, j]), ha='center', va='center', color='black', fontsize=7);
        else:
            plt.text(j, i, str(train_images[197][i, j]), ha='center', va='center', color='white', fontsize=7);

# %% [markdown]
# ### Encoding

# %%
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1)
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1)

# %% [markdown]
# ### Standardizasyon

# %%
train_images = train_images.astype("float32") / 255
test_images = test_images.astype("float32") / 255

# %% [markdown]
# ### Modelleme

# %%
model = Sequential([
    Flatten(input_shape=(28, 28, 1)),
    Dense(units=128, activation="relu", name="layer_1"),
    Dense(units=outputs, activation="softmax", name="output_layer")
])

model.compile(
    loss= "categorical_crossentropy",
    optimizer="adam",
    metrics= [tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), "accuracy"]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  layer_1 (Dense)             (None, 128)               100480
#
#  output_layer (Dense)        (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(train_images, train_labels, epochs=15, batch_size=128, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/15
# 469/469 [==============================] - 2s 2ms/step - loss: 0.3574 - precision: 0.9474 - recall: 0.8501 - accuracy: 0.9017 - val_loss: 0.1924 - val_precision: 0.9590 - val_recall: 0.9333 - val_accuracy: 0.9439
# Epoch 2/15
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1679 - precision: 0.9636 - recall: 0.9419 - accuracy: 0.9525 - val_loss: 0.1415 - val_precision: 0.9674 - val_recall: 0.9510 - val_accuracy: 0.9577
# Epoch 3/15
# 469/469 [==============================] - 1s 2ms/step - loss: 0.1197 - precision: 0.9738 - recall: 0.9597 - accuracy: 0.9664 - val_loss: 0.1127 - val_precision: 0.9746 - val_recall: 0.9612 - val_accuracy: 0.9665
# Epoch 4/15
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0920 - precision: 0.9795 - recall: 0.9686 - accuracy: 0.9737 - val_loss: 0.1000 - val_precision: 0.9754 - val_recall: 0.9663 - val_accuracy: 0.9694
# Epoch 5/15
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0747 - precision: 0.9831 - recall: 0.9753 - accuracy: 0.9789 - val_loss: 0.0853 - val_precision: 0.9772 - val_recall: 0.9692 - val_accuracy: 0.9726
# Epoch 6/15
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0617 - precision: 0.9856 - recall: 0.9793 - accuracy: 0.9822 - val_loss: 0.0834 - val_precision: 0.9777 - val_recall: 0.9714 - val_accuracy: 0.9742
# Epoch 7/15
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0520 - precision: 0.9875 - recall: 0.9827 - accuracy: 0.9850 - val_loss: 0.0823 - val_precision: 0.9779 - val_recall: 0.9707 - val_accuracy: 0.9735
# Epoch 8/15
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0449 - precision: 0.9887 - recall: 0.9846 - accuracy: 0.9864 - val_loss: 0.0803 - val_precision: 0.9782 - val_recall: 0.9727 - val_accuracy: 0.9743
# Epoch 9/15
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0376 - precision: 0.9912 - recall: 0.9875 - accuracy: 0.9892 - val_loss: 0.0761 - val_precision: 0.9794 - val_recall: 0.9747 - val_accuracy: 0.9760
# Epoch 10/15
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0323 - precision: 0.9925 - recall: 0.9895 - accuracy: 0.9910 - val_loss: 0.0732 - val_precision: 0.9789 - val_recall: 0.9744 - val_accuracy: 0.9761
# Epoch 11/15
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0268 - precision: 0.9939 - recall: 0.9917 - accuracy: 0.9928 - val_loss: 0.0764 - val_precision: 0.9790 - val_recall: 0.9751 - val_accuracy: 0.9763
# Epoch 12/15
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0227 - precision: 0.9952 - recall: 0.9932 - accuracy: 0.9942 - val_loss: 0.0717 - val_precision: 0.9801 - val_recall: 0.9766 - val_accuracy: 0.9780
# Epoch 13/15
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0193 - precision: 0.9960 - recall: 0.9943 - accuracy: 0.9951 - val_loss: 0.0785 - val_precision: 0.9786 - val_recall: 0.9748 - val_accuracy: 0.9756
# Epoch 14/15
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0170 - precision: 0.9966 - recall: 0.9956 - accuracy: 0.9961 - val_loss: 0.0764 - val_precision: 0.9796 - val_recall: 0.9765 - val_accuracy: 0.9774
# Epoch 15/15
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0151 - precision: 0.9969 - recall: 0.9958 - accuracy: 0.9962 - val_loss: 0.0841 - val_precision: 0.9778 - val_recall: 0.9748 - val_accuracy: 0.9760

# %% [markdown]
# ### Model Başarısı Değerlendirme

# %%
loss = pd.DataFrame(model.history.history)[["loss","val_loss"]]
loss.plot();
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
acc = pd.DataFrame(model.history.history)[["accuracy","val_accuracy"]]
acc.plot();
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
eval = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 0s 947us/step - loss: 0.0841 - precision: 0.9778 - recall: 0.9748 - accuracy: 0.9760

# %%
pd.DataFrame(data=eval, index=["loss","precision","recall","accuracy"], columns=["Test Skorları"])
# Out:
#            Test Skorları
# loss            0.084057
# precision       0.977831
# recall          0.974800
# accuracy        0.976000

# %% [markdown]
# ### Modeli Kaydetme

# %%
model.save("mnist_model.h5")

# %% [markdown]
# ### Tahmin Yapmak

# %%
sayi = np.random.randint(0, test_images.shape[0])
test_img = test_images[sayi]
test_gercek = test_labels[sayi]
plt.imshow(test_img.reshape(28, 28), cmap="gray");

# %%
test_data = test_images[sayi].reshape(1, 28, 28, 1)
prob = model.predict(test_data, verbose=0)

tahmin = np.argmax(prob)
dogruluk = np.max(prob)
print(f"Tahmin: {tahmin}")
print(f"Doğruluk: %{dogruluk*100:.2f}")
# Out:
# Tahmin: 3
# Doğruluk: %99.90
